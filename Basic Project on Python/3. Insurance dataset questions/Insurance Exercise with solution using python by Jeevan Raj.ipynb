# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#      id  age     sex     bmi  children smoker     region      charges
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 8)

# %% [markdown]
# #### 1. Count for each categories of ‘region

# %%
df.region.value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %% [markdown]
# #### 2. Find 50 records of highest ‘age’ and export data/table to desktop

# %%
a=df.age.sort_values(ascending=False).head(50).index.to_list()
information=df.iloc[a,:]
information.head()
# Out:
#         id  age     sex     bmi  children smoker     region      charges
# 335   1336   64    male  34.500         0     no  southwest  13822.80300
# 603   1604   64  female  39.050         3     no  southeast  16085.12750
# 752   1753   64    male  37.905         0     no  northwest  14210.53595
# 1265  2266   64    male  23.760         0    yes  southeast  26926.51440
# 534   1535   64    male  40.480         0     no  southeast  13831.11520

# %%
# To save the extracted file we use ''to_csv''
information.to_csv('Higest_age_details.csv')

# %% [markdown]
# #### The easy way of writing the code

# %%
df.sort_values('age',ascending=False).reset_index(drop='first').head(50)
# Out:
#       id  age     sex     bmi  children smoker     region      charges
# 0   1336   64    male  34.500         0     no  southwest  13822.80300
# 1   1604   64  female  39.050         3     no  southeast  16085.12750
# 2   1753   64    male  37.905         0     no  northwest  14210.53595
# 3   2266   64    male  23.760         0    yes  southeast  26926.51440
# 4   1535   64    male  40.480         0     no  southeast  13831.11520
# 5   1329   64  female  33.800         1    yes  southwest  47928.03000
# 6   1769   64  female  39.700         0     no  southwest  14319.03100
# 7   2242   64    male  36.960         2    yes  southeast  49577.66240
# 8   1063   64    male  24.700         1     no  northwest  30166.61817
# 9   1802   64  female  35.970         0     no  southeast  14313.84630
# 10  1826   64  female  31.825         2     no  northeast  16069.08475
# 11  1379   64  female  30.115         3     no  northwest  16455.70785
# ...

# %% [markdown]
# #### 4. Describe the schema of table

# %%
df.describe()
# Out:
#                 id          age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean   1669.500000    39.207025    30.663397     1.094918  13270.422265
# std     386.391641    14.049960     6.098187     1.205493  12110.011237
# min    1001.000000    18.000000    15.960000     0.000000   1121.873900
# 25%    1335.250000    27.000000    26.296250     0.000000   4740.287150
# 50%    1669.500000    39.000000    30.400000     1.000000   9382.033000
# 75%    2003.750000    51.000000    34.693750     2.000000  16639.912515
# max    2338.000000    64.000000    53.130000     5.000000  63770.428010

# %%
df.describe(include='all')
# Out:
#                  id          age   sex          bmi     children smoker  \
# count   1338.000000  1338.000000  1338  1338.000000  1338.000000   1338
# unique          NaN          NaN     2          NaN          NaN      2
# top             NaN          NaN  male          NaN          NaN     no
# freq            NaN          NaN   676          NaN          NaN   1064
# mean    1669.500000    39.207025   NaN    30.663397     1.094918    NaN
# std      386.391641    14.049960   NaN     6.098187     1.205493    NaN
# min     1001.000000    18.000000   NaN    15.960000     0.000000    NaN
# 25%     1335.250000    27.000000   NaN    26.296250     0.000000    NaN
# 50%     1669.500000    39.000000   NaN    30.400000     1.000000    NaN
# 75%     2003.750000    51.000000   NaN    34.693750     2.000000    NaN
# max     2338.000000    64.000000   NaN    53.130000     5.000000    NaN
#
#            region       charges
# count        1338   1338.000000
# unique          4           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %% [markdown]
# #### 5. Create view name as ‘gender’ where users can not see ‘sex’ [Hint: first run appropriate query then create view]

# %%
df.head()
# Out:
#      id  age     sex     bmi  children smoker     region      charges
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
gender = df[['id', 'age', 'bmi', 'children', 'smoker', 'region', 'charges']]
gender.head()
# Out:
#      id  age     bmi  children smoker     region      charges
# 0  1001   19  27.900         0    yes  southwest  16884.92400
# 1  1002   18  33.770         1     no  southeast   1725.55230
# 2  1003   28  33.000         3     no  southeast   4449.46200
# 3  1004   33  22.705         0     no  northwest  21984.47061
# 4  1005   32  28.880         0     no  northwest   3866.85520

# %% [markdown]
# #### 7. Count how many are ‘northwest’ insurance holders

# %%
len(df[df.region=='northwest'])
# Out:
# 325

# %% [markdown]
# #### 8. Count how many insurance holders were ‘femail’

# %%
len(df[df.sex=='female'])
# Out:
# 662

# %%
df.head()
# Out:
#      id  age     sex     bmi  children smoker     region      charges
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# #### 10. Create a new column ‘ratio’ which is age multiply by bmi

# %%
df['ratio']=df.age*df.bmi

# %%
df.head()
# Out:
#      id  age     sex     bmi  children smoker     region      charges    ratio
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400  530.100
# 1  1002   18    male  33.770         1     no  southeast   1725.55230  607.860
# 2  1003   28    male  33.000         3     no  southeast   4449.46200  924.000
# 3  1004   33    male  22.705         0     no  northwest  21984.47061  749.265
# 4  1005   32    male  28.880         0     no  northwest   3866.85520  924.160

# %% [markdown]
# #### 11. Arrange the table from high to low according to charges

# %%
df.sort_values('charges',ascending=False).reset_index(drop='first')
# Out:
#         id  age     sex     bmi  children smoker     region      charges  \
# 0     1544   54  female  47.410         0    yes  southeast  63770.42801
# 1     2301   45    male  30.360         0    yes  southeast  62592.87309
# 2     2231   52    male  34.485         3    yes  northwest  60021.39897
# 3     1578   31  female  38.095         1    yes  northeast  58571.07448
# 4     1820   33  female  35.530         0    yes  northwest  55135.40209
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  1023   18    male  34.100         0     no  southeast   1137.01100
# 1334  1664   18    male  33.660         0     no  southeast   1136.39940
# 1335  2245   18    male  33.330         0     no  southeast   1135.94070
# 1336  1809   18    male  30.140         0     no  southeast   1131.50660
# 1337  1941   18    male  23.210         0     no  southeast   1121.87390
#
#          ratio
# 0     2560.140
# 1     1366.200
# 2     1793.220
# 3     1180.945
# ...

# %% [markdown]
# #### 12. Find MAX of ‘charges’

# %%
df.charges.max()
# Out:
# 63770.42801

# %% [markdown]
# #### 13. Find MIN of ‘charges’

# %%
df.charges.min()
# Out:
# 1121.8739

# %% [markdown]
# #### 14. Find average of ‘charges’ of male and female

# %%
df.groupby(by='sex')['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %%
df.head()
# Out:
#      id  age     sex     bmi  children smoker     region      charges    ratio
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400  530.100
# 1  1002   18    male  33.770         1     no  southeast   1725.55230  607.860
# 2  1003   28    male  33.000         3     no  southeast   4449.46200  924.000
# 3  1004   33    male  22.705         0     no  northwest  21984.47061  749.265
# 4  1005   32    male  28.880         0     no  northwest   3866.85520  924.160

# %% [markdown]
# #### 15. Write a Query to rename column name sex to Gender

# %%
df.rename(columns={'sex':'Gender'},inplace=True)

# %%
df.rename(columns={'sex':'Gender'},inplace=True)

# %%
df.head()
# Out:
#      id  age  Gender     bmi  children smoker     region      charges    ratio
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400  530.100
# 1  1002   18    male  33.770         1     no  southeast   1725.55230  607.860
# 2  1003   28    male  33.000         3     no  southeast   4449.46200  924.000
# 3  1004   33    male  22.705         0     no  northwest  21984.47061  749.265
# 4  1005   32    male  28.880         0     no  northwest   3866.85520  924.160

# %% [markdown]
# #### 16. Add new column as HL_Charges where more than average charges should be categorized as HIGH and less than average charges should be categorized as LOW

# %%
avg=df.charges.mean()
df['HL_Charges']=df['charges'].apply(lambda x: 'HIGH' if x>avg else 'LOW')

# %%
df.head()
# Out:
#      id  age  Gender     bmi  children smoker     region      charges  \
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520
#
#      ratio HL_Charges
# 0  530.100       HIGH
# 1  607.860        LOW
# 2  924.000        LOW
# 3  749.265       HIGH
# 4  924.160        LOW

# %% [markdown]
# #### The above is one way of writing the code (we can write the code in other way aswell)

# %%
# Now will drop the HL_Charges
df.drop('HL_Charges',axis=1,inplace=True)

# %%
df.head()
# Out:
#      id  age  Gender     bmi  children smoker     region      charges    ratio
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400  530.100
# 1  1002   18    male  33.770         1     no  southeast   1725.55230  607.860
# 2  1003   28    male  33.000         3     no  southeast   4449.46200  924.000
# 3  1004   33    male  22.705         0     no  northwest  21984.47061  749.265
# 4  1005   32    male  28.880         0     no  northwest   3866.85520  924.160

# %%
df['HL_Charges']=np.where(df.charges>avg,'HIGH','LOW')

# %%
df.head()
# Out:
#      id  age  Gender     bmi  children smoker     region      charges  \
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520
#
#      ratio HL_Charges
# 0  530.100       HIGH
# 1  607.860        LOW
# 2  924.000        LOW
# 3  749.265       HIGH
# 4  924.160        LOW

# %% [markdown]
# #### 17. Change location/position of ‘smoker’ and bring before ‘children’

# %%
df.head()
# Out:
#      id  age  Gender     bmi  children smoker     region      charges  \
# 0  1001   19  female  27.900         0    yes  southwest  16884.92400
# 1  1002   18    male  33.770         1     no  southeast   1725.55230
# 2  1003   28    male  33.000         3     no  southeast   4449.46200
# 3  1004   33    male  22.705         0     no  northwest  21984.47061
# 4  1005   32    male  28.880         0     no  northwest   3866.85520
#
#      ratio HL_Charges
# 0  530.100       HIGH
# 1  607.860        LOW
# 2  924.000        LOW
# 3  749.265       HIGH
# 4  924.160        LOW

# %%
df.columns
# Out:
# Index(['id', 'age', 'Gender', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'ratio', 'HL_Charges'],
#       dtype='object')

# %%
df=df.reindex(columns=['id', 'age', 'Gender', 'bmi', 'smoker', 'children', 'region', 'charges','ratio', 'HL_Charges'])

# %%
df.head()
# Out:
#      id  age  Gender     bmi smoker  children     region      charges  \
# 0  1001   19  female  27.900    yes         0  southwest  16884.92400
# 1  1002   18    male  33.770     no         1  southeast   1725.55230
# 2  1003   28    male  33.000     no         3  southeast   4449.46200
# 3  1004   33    male  22.705     no         0  northwest  21984.47061
# 4  1005   32    male  28.880     no         0  northwest   3866.85520
#
#      ratio HL_Charges
# 0  530.100       HIGH
# 1  607.860        LOW
# 2  924.000        LOW
# 3  749.265       HIGH
# 4  924.160        LOW

# %% [markdown]
# #### 18. Show top 20 records

# %%
df.head(20)
# Out:
#       id  age  Gender     bmi smoker  children     region      charges  \
# 0   1001   19  female  27.900    yes         0  southwest  16884.92400
# 1   1002   18    male  33.770     no         1  southeast   1725.55230
# 2   1003   28    male  33.000     no         3  southeast   4449.46200
# 3   1004   33    male  22.705     no         0  northwest  21984.47061
# 4   1005   32    male  28.880     no         0  northwest   3866.85520
# 5   1006   31  female  25.740     no         0  southeast   3756.62160
# 6   1007   46  female  33.440     no         1  southeast   8240.58960
# 7   1008   37  female  27.740     no         3  northwest   7281.50560
# 8   1009   37    male  29.830     no         2  northeast   6406.41070
# 9   1010   60  female  25.840     no         0  northwest  28923.13692
# 10  1011   25    male  26.220     no         0  northeast   2721.32080
# 11  1012   62  female  26.290    yes         0  southeast  27808.72510
# ...

# %% [markdown]
# #### 19. Show bottom 20 records

# %%
df.tail(20)
# Out:
#         id  age  Gender     bmi smoker  children     region      charges  \
# 1318  2319   35    male  39.710     no         4  northeast  19496.71917
# 1319  2320   39  female  26.315     no         2  northwest   7201.70085
# 1320  2321   31    male  31.065     no         3  northwest   5425.02335
# 1321  2322   62    male  26.695    yes         0  northeast  28101.33305
# 1322  2323   62    male  38.830     no         0  southeast  12981.34570
# 1323  2324   42  female  40.370    yes         2  southeast  43896.37630
# 1324  2325   31    male  25.935     no         1  northwest   4239.89265
# 1325  2326   61    male  33.535     no         0  northeast  13143.33665
# 1326  2327   42  female  32.870     no         0  northeast   7050.02130
# 1327  2328   51    male  30.030     no         1  southeast   9377.90470
# 1328  2329   23  female  24.225     no         2  northeast  22395.74424
# 1329  2330   52    male  38.600     no         2  southwest  10325.20600
# ...

# %% [markdown]
# #### 20. Randomly select 20% of records and export to desktop

# %%
df.sample(frac=.2)          # You can see whenever you run the sample is changing and it is printing 20% of the data randomly
                            # frac = fraction
# Out:
#         id  age  Gender     bmi smoker  children     region      charges  \
# 1227  2228   42    male  37.180     no         2  southeast   7162.01220
# 1307  2308   32    male  28.120    yes         4  northwest  21472.47880
# 1126  2127   55    male  29.900     no         0  southwest  10214.63600
# 245   1246   54    male  30.020     no         0  northwest  24476.47851
# 125   1126   26  female  28.785     no         0  northeast   3385.39915
# ...    ...  ...     ...     ...    ...       ...        ...          ...
# 404   1405   31    male  20.400     no         0  southwest   3260.19900
# 104   1105   34  female  27.500     no         1  southwest   5003.85300
# 962   1963   63  female  35.200     no         1  southeast  14474.67500
# 473   1474   47  female  33.345     no         0  northeast  20878.78443
# 1061  2062   57    male  27.940     no         1  southeast  11554.22360
#
#          ratio HL_Charges
# 1227  1561.560        LOW
# 1307   899.840       HIGH
# ...

# %%
# whatif if you want to print random 20% of the data and when ever i load the data those random state is same 
# To resolve those issue will use random state with seed = n
df.sample(frac=.2,random_state=1)
# Out:
#         id  age  Gender     bmi smoker  children     region      charges  \
# 559   1560   19    male  35.530     no         0  northwest   1646.42970
# 1087  2088   57    male  31.540     no         0  northwest  11353.22760
# 1020  2021   51    male  37.000     no         0  southwest   8798.59300
# 460   1461   49  female  36.630     no         3  southeast  10381.47870
# 802   1803   21    male  22.300     no         1  southwest   2103.08000
# ...    ...  ...     ...     ...    ...       ...        ...          ...
# 682   1683   39    male  35.300    yes         2  southwest  40103.89000
# 629   1630   44  female  38.950    yes         0  northwest  42983.45850
# 893   1894   47    male  38.940    yes         2  southeast  44202.65360
# 807   1808   19  female  36.575     no         0  northwest   2136.88225
# 1165  2166   35  female  26.125     no         0  northeast   5227.98875
#
#          ratio HL_Charges
# 559    675.070        LOW
# 1087  1797.780        LOW
# ...

# %% [markdown]
# #### 21. Remove column ‘ratio’

# %%
df.drop('ratio',axis=1,inplace=True)

# %%
df.head()
# Out:
#      id  age  Gender     bmi smoker  children     region      charges  \
# 0  1001   19  female  27.900    yes         0  southwest  16884.92400
# 1  1002   18    male  33.770     no         1  southeast   1725.55230
# 2  1003   28    male  33.000     no         3  southeast   4449.46200
# 3  1004   33    male  22.705     no         0  northwest  21984.47061
# 4  1005   32    male  28.880     no         0  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %% [markdown]
# #### 23. Create a view called Female_HL_Charges that shows only those data where HL_Charges is High, Female, Smokers and with 0 children

# %%
Female_HL_Charges=df[(df.HL_Charges =='HIGH')&(df.Gender=='female')&(df.smoker=='yes')&(df.children==0)]
Female_HL_Charges
# Out:
#         id  age  Gender     bmi smoker  children     region      charges  \
# 0     1001   19  female  27.900    yes         0  southwest  16884.92400
# 11    1012   62  female  26.290    yes         0  southeast  27808.72510
# 64    1065   20  female  22.420    yes         0  northwest  14711.74380
# 70    1071   27  female  24.750    yes         0  southeast  16577.77950
# 86    1087   57  female  31.160    yes         0  northwest  43578.93940
# 126   1127   19  female  28.300    yes         0  southwest  17081.08000
# 153   1154   42  female  23.370    yes         0  northeast  19964.74630
# 160   1161   42  female  26.600    yes         0  northwest  21348.70600
# 161   1162   18  female  36.850    yes         0  southeast  36149.48350
# 175   1176   63  female  37.700    yes         0  southwest  48824.45000
# 203   1204   27  female  36.080    yes         0  southeast  37133.89820
# 244   1245   63  female  27.740    yes         0  northeast  29523.16560
# ...

# %% [markdown]
# #### 24. Update children column if there is 0 children then make it as Zero Children, if 1 then one_children, if 2 then two_children, if 3 then three_children, if 4 then four_children if 5 then five_children else print it as More_than_five_children

# %%
df.head()
# Out:
#      id  age  Gender     bmi smoker  children     region      charges  \
# 0  1001   19  female  27.900    yes         0  southwest  16884.92400
# 1  1002   18    male  33.770     no         1  southeast   1725.55230
# 2  1003   28    male  33.000     no         3  southeast   4449.46200
# 3  1004   33    male  22.705     no         0  northwest  21984.47061
# 4  1005   32    male  28.880     no         0  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %%
df['children'] = df['children'].apply(lambda x: 'Zero Children' if x== 0 else 'one_children' if x == 1 else 
                     'two_children'  if x == 2 else 'three_children' if x == 3 else
                     'four_children' if x == 4 else  'five_children' if x == 5 else 'More_than_five_children')

# %%
df.head()
# Out:
#      id  age  Gender     bmi smoker        children     region      charges  \
# 0  1001   19  female  27.900    yes   Zero Children  southwest  16884.92400
# 1  1002   18    male  33.770     no    one_children  southeast   1725.55230
# 2  1003   28    male  33.000     no  three_children  southeast   4449.46200
# 3  1004   33    male  22.705     no   Zero Children  northwest  21984.47061
# 4  1005   32    male  28.880     no   Zero Children  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#      id  age  Gender     bmi smoker        children     region      charges  \
# 0  1001   19  female  27.900    yes   Zero Children  southwest  16884.92400
# 1  1002   18    male  33.770     no    one_children  southeast   1725.55230
# 2  1003   28    male  33.000     no  three_children  southeast   4449.46200
# 3  1004   33    male  22.705     no   Zero Children  northwest  21984.47061
# 4  1005   32    male  28.880     no   Zero Children  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %%
df1['smoker']=pd.get_dummies(df1.smoker,drop_first=True)
df1.head()
# Out:
#      id  age  Gender     bmi  smoker        children     region      charges  \
# 0  1001   19  female  27.900       1   Zero Children  southwest  16884.92400
# 1  1002   18    male  33.770       0    one_children  southeast   1725.55230
# 2  1003   28    male  33.000       0  three_children  southeast   4449.46200
# 3  1004   33    male  22.705       0   Zero Children  northwest  21984.47061
# 4  1005   32    male  28.880       0   Zero Children  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %%
df1['smoker']=df1['smoker'].apply(lambda x: 1  if x=='yes' else 0)
df1.head()
# Out:
#      id  age  Gender     bmi  smoker        children     region      charges  \
# 0  1001   19  female  27.900       0   Zero Children  southwest  16884.92400
# 1  1002   18    male  33.770       0    one_children  southeast   1725.55230
# 2  1003   28    male  33.000       0  three_children  southeast   4449.46200
# 3  1004   33    male  22.705       0   Zero Children  northwest  21984.47061
# 4  1005   32    male  28.880       0   Zero Children  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW

# %%
df1['smoker']=np.where(df.smoker=='yes',1,0)
df1.head()
# Out:
#      id  age  Gender     bmi  smoker        children     region      charges  \
# 0  1001   19  female  27.900       1   Zero Children  southwest  16884.92400
# 1  1002   18    male  33.770       0    one_children  southeast   1725.55230
# 2  1003   28    male  33.000       0  three_children  southeast   4449.46200
# 3  1004   33    male  22.705       0   Zero Children  northwest  21984.47061
# 4  1005   32    male  28.880       0   Zero Children  northwest   3866.85520
#
#   HL_Charges
# 0       HIGH
# 1        LOW
# 2        LOW
# 3       HIGH
# 4        LOW
